# %%
from gssutils import *
from databaker.framework import *
import pandas as pd
import datetime

def left(s, amount):
    return s[:amount]

def right(s, amount):
    return s[-amount:]

def mid(s, offset, amount):
    return s[offset:offset+amount]

year = right(str(datetime.datetime.now().year),2)

scraper = Scraper('https://www.gov.uk/government/statistics/family-resources-survey-financial-year-201718')
dist = scraper.distribution(title=lambda t: 'Disability data tables (XLS)' in t)
tab = next(t for t in dist.as_databaker() if t.name == '4_2')

# %%
tidied_sheets = []
        
cell = tab.excel_ref("B9")

remove = tab.filter('Percentage of people').expand(RIGHT).expand(LEFT).expand(DOWN)
    
year = cell.expand(DOWN).is_not_blank() - remove

gender = cell.shift(2,0).expand(RIGHT).is_not_blank()

observations = gender.fill(DOWN).is_not_blank() - remove

dimensions = [
        #HDimConst('Dimension Name', 'Variable'),
        HDim(year, 'Period', DIRECTLY, LEFT), 
        HDim(gender, 'Gender', DIRECTLY, ABOVE), 
        HDimConst('Age Group', 'All people'),
        HDimConst('Measure type','Count'),
        HDimConst('Unit','People (Millions)')    
]
    
c1 = ConversionSegment(observations, dimensions, processTIMEUNIT=True)
savepreviewhtml(c1, fname="Preview.html")
# Out:
# tablepart '4_2' written #injblock1015
# javascript calculated
# C:\Users\Red\Documents\COGS\Disability\DWP-Family-Resources-Survey-Disability\Preview.html

# %%
new_table = c1.topandas()
import numpy as np
new_table['OBS'].replace('', np.nan, inplace=True)
new_table.dropna(subset=['OBS'], inplace=True)
new_table.rename(columns={'OBS': 'Value'}, inplace=True)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Period'] = new_table['Period'].map(
    lambda x: f'gregorian-interval/{left(x,2) + right(x,2)}-03-31T00:00:00/P1Y')
new_table['Age Group'] = new_table['Age Group'].map(
    lambda x: left(x, len(x) - 1) if x.endswith('1') else x)
new_table = new_table[['Period','Gender','Age Group','Measure type','Value','Unit']]
new_table
# Out:
#                                         Period   Gender   Age Group  \
# 0   gregorian-interval/2008-03-31T00:00:00/P1Y    Males  All people
# 1   gregorian-interval/2008-03-31T00:00:00/P1Y  Females  All people
# 2   gregorian-interval/2009-03-31T00:00:00/P1Y    Males  All people
# 3   gregorian-interval/2009-03-31T00:00:00/P1Y  Females  All people
# 4   gregorian-interval/2010-03-31T00:00:00/P1Y    Males  All people
# 5   gregorian-interval/2010-03-31T00:00:00/P1Y  Females  All people
# 6   gregorian-interval/2011-03-31T00:00:00/P1Y    Males  All people
# 7   gregorian-interval/2011-03-31T00:00:00/P1Y  Females  All people
# 8   gregorian-interval/2012-03-31T00:00:00/P1Y    Males  All people
# 9   gregorian-interval/2012-03-31T00:00:00/P1Y  Females  All people
# 10  gregorian-interval/2013-03-31T00:00:00/P1Y    Males  All people
# 11  gregorian-interval/2013-03-31T00:00:00/P1Y  Females  All people
# 12  gregorian-interval/2014-03-31T00:00:00/P1Y    Males  All people
# 13  gregorian-interval/2014-03-31T00:00:00/P1Y  Females  All people
# 14  gregorian-interval/2015-03-31T00:00:00/P1Y    Males  All people
# 15  gregorian-interval/2015-03-31T00:00:00/P1Y  Females  All people
# 16  gregorian-interval/2016-03-31T00:00:00/P1Y    Males  All people
# 17  gregorian-interval/2016-03-31T00:00:00/P1Y  Females  All people
# 18  gregorian-interval/2017-03-31T00:00:00/P1Y    Males  All people
# 19  gregorian-interval/2017-03-31T00:00:00/P1Y  Females  All people
# 20  gregorian-interval/2018-03-31T00:00:00/P1Y    Males  All people
# 21  gregorian-interval/2018-03-31T00:00:00/P1Y  Females  All people
#
#    Measure type  Value               Unit
# 0         Count      5  People (Millions)
# 1         Count      5  People (Millions)
# 2         Count      5  People (Millions)
# 3         Count      6  People (Millions)
# 4         Count      5  People (Millions)
# 5         Count      6  People (Millions)
# 6         Count      5  People (Millions)
# 7         Count      6  People (Millions)
# 8         Count      5  People (Millions)
# 9         Count      6  People (Millions)
# 10        Count      5  People (Millions)
# 11        Count      6  People (Millions)
# 12        Count      5  People (Millions)
# 13        Count      6  People (Millions)
# 14        Count      5  People (Millions)
# 15        Count      7  People (Millions)
# 16        Count      6  People (Millions)
# 17        Count      7  People (Millions)
# 18        Count      6  People (Millions)
# 19        Count      7  People (Millions)
# 20        Count      6  People (Millions)
# 21        Count      7  People (Millions)

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

TAB_NAME = 'Disability-prevalence-by-gender-2007-08-to-2017-18'

new_table.drop_duplicates().to_csv(destinationFolder / f'{TAB_NAME}.csv', index = False)
