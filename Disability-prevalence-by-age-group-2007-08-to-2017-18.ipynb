# %%
from gssutils import *
from databaker.framework import *
import pandas as pd
import datetime

def left(s, amount):
    return s[:amount]

def right(s, amount):
    return s[-amount:]

def mid(s, offset, amount):
    return s[offset:offset+amount]

year = right(str(datetime.datetime.now().year),2)

scraper = Scraper('https://www.gov.uk/government/statistics/family-resources-survey-financial-year-201718')
dist = scraper.distribution(title=lambda t: 'Disability data tables (XLS)' in t)
tab = next(t for t in dist.as_databaker() if t.name == '4_1')

# %%
tidied_sheets = []
        
cell = tab.filter("Year")
    
year = cell.shift(RIGHT).expand(DOWN).is_not_blank().shift(LEFT)

remove = tab.filter("Sample size").expand(DOWN)

age = cell.shift(RIGHT).expand(RIGHT).is_not_blank() - remove

observations = year.shift(RIGHT).expand(RIGHT).is_not_blank() - remove

dimensions = [
        #HDimConst('Dimension Name', 'Variable'),
        HDim(year, 'Period', DIRECTLY, LEFT), 
        HDim(age, 'Age Group', DIRECTLY, ABOVE),
        HDimConst('Measure type','Percentage'),
        HDimConst('Unit','People')    
]
    
c1 = ConversionSegment(observations, dimensions, processTIMEUNIT=True)
savepreviewhtml(c1, fname="Preview.html")
# Out:
# tablepart '4_1' written #injblock1001
# javascript calculated
# C:\Users\Red\Documents\COGS\Disability\DWP-Family-Resources-Survey-Disability\Preview.html

# %%
new_table = c1.topandas()
import numpy as np
new_table['OBS'].replace('', np.nan, inplace=True)
new_table.dropna(subset=['OBS'], inplace=True)
new_table.rename(columns={'OBS': 'Value'}, inplace=True)
new_table['Value'] = new_table['Value'].astype(int)
new_table['Period'] = new_table['Period'].map(
    lambda x: f'gregorian-interval/{left(x,2) + right(x,2)}-03-31T00:00:00/P1Y')
new_table['Age Group'] = new_table['Age Group'].map(
    lambda x: left(x, len(x) - 1) if x.endswith('1') else x)
new_table = new_table[['Period','Age Group','Measure type','Value','Unit']]
new_table
# Out:
#                                         Period                 Age Group  \
# 4   gregorian-interval/2008-03-31T00:00:00/P1Y                All people
# 5   gregorian-interval/2008-03-31T00:00:00/P1Y        Working-age adults
# 6   gregorian-interval/2008-03-31T00:00:00/P1Y  State Pension age adults
# 7   gregorian-interval/2008-03-31T00:00:00/P1Y                  Children
# 8   gregorian-interval/2009-03-31T00:00:00/P1Y                All people
# 9   gregorian-interval/2009-03-31T00:00:00/P1Y        Working-age adults
# 10  gregorian-interval/2009-03-31T00:00:00/P1Y  State Pension age adults
# 11  gregorian-interval/2009-03-31T00:00:00/P1Y                  Children
# 12  gregorian-interval/2010-03-31T00:00:00/P1Y                All people
# 13  gregorian-interval/2010-03-31T00:00:00/P1Y        Working-age adults
# 14  gregorian-interval/2010-03-31T00:00:00/P1Y  State Pension age adults
# 15  gregorian-interval/2010-03-31T00:00:00/P1Y                  Children
# 16  gregorian-interval/2011-03-31T00:00:00/P1Y                All people
# 17  gregorian-interval/2011-03-31T00:00:00/P1Y        Working-age adults
# 18  gregorian-interval/2011-03-31T00:00:00/P1Y  State Pension age adults
# 19  gregorian-interval/2011-03-31T00:00:00/P1Y                  Children
# 20  gregorian-interval/2012-03-31T00:00:00/P1Y                All people
# 21  gregorian-interval/2012-03-31T00:00:00/P1Y        Working-age adults
# 22  gregorian-interval/2012-03-31T00:00:00/P1Y  State Pension age adults
# 23  gregorian-interval/2012-03-31T00:00:00/P1Y                  Children
# 24  gregorian-interval/2013-03-31T00:00:00/P1Y                All people
# 25  gregorian-interval/2013-03-31T00:00:00/P1Y        Working-age adults
# 26  gregorian-interval/2013-03-31T00:00:00/P1Y  State Pension age adults
# 27  gregorian-interval/2013-03-31T00:00:00/P1Y                  Children
# 28  gregorian-interval/2014-03-31T00:00:00/P1Y                All people
# 29  gregorian-interval/2014-03-31T00:00:00/P1Y        Working-age adults
# 30  gregorian-interval/2014-03-31T00:00:00/P1Y  State Pension age adults
# 31  gregorian-interval/2014-03-31T00:00:00/P1Y                  Children
# 32  gregorian-interval/2015-03-31T00:00:00/P1Y                All people
# 33  gregorian-interval/2015-03-31T00:00:00/P1Y        Working-age adults
# 34  gregorian-interval/2015-03-31T00:00:00/P1Y  State Pension age adults
# 35  gregorian-interval/2015-03-31T00:00:00/P1Y                  Children
# 36  gregorian-interval/2016-03-31T00:00:00/P1Y                All people
# 37  gregorian-interval/2016-03-31T00:00:00/P1Y        Working-age adults
# 38  gregorian-interval/2016-03-31T00:00:00/P1Y  State Pension age adults
# 39  gregorian-interval/2016-03-31T00:00:00/P1Y                  Children
# 40  gregorian-interval/2017-03-31T00:00:00/P1Y                All people
# 41  gregorian-interval/2017-03-31T00:00:00/P1Y        Working-age adults
# 42  gregorian-interval/2017-03-31T00:00:00/P1Y  State Pension age adults
# 43  gregorian-interval/2017-03-31T00:00:00/P1Y                  Children
# 44  gregorian-interval/2018-03-31T00:00:00/P1Y                All people
# 45  gregorian-interval/2018-03-31T00:00:00/P1Y        Working-age adults
# 46  gregorian-interval/2018-03-31T00:00:00/P1Y  State Pension age adults
# 47  gregorian-interval/2018-03-31T00:00:00/P1Y                  Children
#
#    Measure type  Value    Unit
# 4    Percentage     18  People
# 5    Percentage     14  People
# 6    Percentage     46  People
# 7    Percentage      6  People
# 8    Percentage     19  People
# 9    Percentage     14  People
# 10   Percentage     47  People
# 11   Percentage      6  People
# 12   Percentage     19  People
# 13   Percentage     15  People
# 14   Percentage     45  People
# 15   Percentage      6  People
# 16   Percentage     19  People
# 17   Percentage     15  People
# 18   Percentage     45  People
# 19   Percentage      6  People
# 20   Percentage     19  People
# 21   Percentage     16  People
# 22   Percentage     45  People
# 23   Percentage      6  People
# 24   Percentage     19  People
# 25   Percentage     16  People
# 26   Percentage     43  People
# 27   Percentage      7  People
# 28   Percentage     19  People
# 29   Percentage     16  People
# 30   Percentage     42  People
# 31   Percentage      7  People
# 32   Percentage     20  People
# 33   Percentage     17  People
# 34   Percentage     45  People
# 35   Percentage      7  People
# 36   Percentage     21  People
# 37   Percentage     18  People
# 38   Percentage     44  People
# 39   Percentage      7  People
# 40   Percentage     22  People
# 41   Percentage     19  People
# 42   Percentage     45  People
# 43   Percentage      8  People
# 44   Percentage     21  People
# 45   Percentage     18  People
# 46   Percentage     44  People
# 47   Percentage      8  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

TAB_NAME = 'Disability-prevalence-by-age-group-2007-08-to-2017-18'

new_table.drop_duplicates().to_csv(destinationFolder / f'{TAB_NAME}.csv', index = False)
